# %% [markdown]
# # Explore data augmentations
#
# This notebook will be used to test different data augmentation strategies. In your config file, you can modify the augmentations by adding `data_augmentation_options`. For example, I would like to add a random RGB to gray transform with a probability of 0.2:
# ```
# data_augmentation_options {
#     random_rgb_to_gray {
#     probability: 0.2
#     }
# ```
#
# A complete list of augmentation is provided the [`preprocessor.proto` file of the Tf Object Detection API](https://github.com/tensorflow/models/blob/master/research/object_detection/protos/preprocessor.proto).

# %% [markdown]
# ### Helper functions

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Rectangle
import tensorflow as tf

# %%
def recenter_image(image):
    # ssd preprocessing
    image += [123.68, 116.779, 103.939]
    return image

def display_instances(image, bboxes, classes):
    image = recenter_image(image)
    w, h, _ = image.shape
    # resize the bboxes
    bboxes[:, [0, 2]] *= w
    bboxes[:, [1, 3]] *= h
    
    f, ax = plt.subplots(1, figsize=(5, 5))
    ax.imshow(image.astype(np.uint8))
    print(f'dimension 0: {image.shape[0]}, dimensions 1: {image.shape[1]}')
    colormap = {1: [1,0,0], 2: [0,0,1], 4:[0,1,0]}
    for bb, cl in zip(bboxes, classes):
        y1, x1, y2, x2 = bb
        rec = Rectangle((x1, y1), x2-x1, y2-y1, facecolor='none', edgecolor = cl, linewidth=2)
        ax.add_patch(rec)
    f.tight_layout()
    plt.show()
    # f.savefig('quality.png')

def display_batch(batch):
    # get images, bboxes and classes
    batched_images = batch[0]['image'].numpy()
    batched_bboxes = batch[1]['groundtruth_boxes'].numpy()
    batched_classes = batch[1]['groundtruth_classes'].numpy()
    num_bboxes = batch[1]['num_groundtruth_boxes'].numpy()
    batch_size = batched_images.shape[0]
    for idx in range(batch_size):
        display_instances(batched_images[idx, ...], 
                          batched_bboxes[idx, :num_bboxes[idx], :],
                          batched_classes[idx, ...])

# %% [markdown]
# ### Display augmentations

# %%
from utils import get_train_input

# %%
from utils import get_module_logger
import logging
logger = get_module_logger(__name__)
tf.compat.v1.logging.set_verbosity(30)
# train_dataset = get_train_input("augmentations/pipeline_test_random_horizontal_flip.config")
# train_dataset = get_train_input("augmentations/pipeline_test_random_crop_image.config")
# train_dataset = get_train_input("augmentations/pipeline_test_random_adjust_hue.config")
train_dataset = get_train_input("augmentations/pipeline_test_random_jpeg_quality.config")

# %%
# %matplotlib inline

for batch in train_dataset.take(1):
    display_batch(batch)
# Out:
# dimension 0: 640, dimensions 1: 640
# dimension 0: 640, dimensions 1: 640
# dimension 0: 640, dimensions 1: 640
# dimension 0: 640, dimensions 1: 640
